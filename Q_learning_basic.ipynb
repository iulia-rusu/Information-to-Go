# %%
# __future__ import should always be first
from __future__ import annotations

# Standard library imports
from collections import defaultdict

# Third-party imports
import torch
import numpy as np
import torch.nn as nn
from torch.distributions.categorical import Categorical

# Gymnasium & Minigrid imports
import gymnasium as gym  # Correct way to import Gymnasium
from minigrid.core.constants import COLOR_NAMES
from minigrid.core.constants import DIR_TO_VEC
from minigrid.core.grid import Grid
from minigrid.core.actions import Actions
from minigrid.core.mission import MissionSpace
from minigrid.core.world_object import Door, Goal, Key, Wall
from minigrid.manual_control import ManualControl
from minigrid.minigrid_env import MiniGridEnv
from gymnasium.utils.play import play
import pandas as pd
# Visualization imports
import matplotlib.pyplot as plt

# %%
class SimpleEnv(MiniGridEnv):
    def __init__(
            self, 
            size=10, 
            agent_start_pos=(1, 8), 
            agent_start_dir=0, 
            max_steps=256, 
            **kwargs,
    ):
        self.agent_start_pos = agent_start_pos
        self.agent_start_dir = agent_start_dir
        self.goal_pos = (8, 1)
        
        
        
        mission_space = MissionSpace(mission_func=self._gen_mission)

        super().__init__(
            mission_space=mission_space,
            grid_size=size,
            max_steps=max_steps,
            **kwargs,
        )

        self.action_space = gym.spaces.Discrete(3)

        #



    @staticmethod
    def _gen_mission():
        return "Find the shortest path"

    def _gen_grid(self, width, height):
        #create gird
        self.grid = Grid(width, height)
        #place barrier
        self.grid.wall_rect(0, 0, width, height)
        #place goal
        self.put_obj(Goal(), 8, 1)
        #place walls
        for i in range(1, width // 2):
            self.grid.set(i, width - 4, Wall())
            self.grid.set(i + width // 2 - 1, width - 7, Wall())
        #place agent
        if self.agent_start_pos is not None:
            self.agent_pos = self.agent_start_pos #check this
            self.agent_dir = self.agent_start_dir
        else:
            self.place_agent()

        self.mission = "find the shortest path"
    
    def count_states(self):
        free_cells = sum(1 for x in range(self.grid.width)
                      for y in range(self.grid.height)
                      if not self.grid.get(x, y)) * 4
        return free_cells

# %%
env = SimpleEnv(render_mode='human')  # Create the environment with human rendering
# env.reset()

# %%
obs = env.reset()  # Reset the environment to start a new episode

# %%
grid_encoding = env.grid.encode()

# %%
grid_encoding.shape
# Out:
# (10, 10, 3)

# %%
class Qlearning:
    def __init__(
        self,
        env,
        learning_rate = 0.9,
        discount_factor = 0.9,
        epsilon = 0.5,
        epochs = 1000
         
    ):
        self.env = env # MiniGrid environment called from the class Minigrid
        self.num_states = np.int64(env.count_states())
        self.num_actions = env.action_space.n
        self.Q_table = np.zeros((((env.width -2) * (env.height -2) *4), self.num_actions)) # Q table has goal states in it as well
        # print(f"Q table shape: {self.Q_table.shape}")
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor # discount factor
        self.epsilon =  epsilon # exploration probability
        self.epochs = epochs


        self.allowed_state_idx = self.find_state_indexes(env)
        # print(f"allowed state indexes: {self.allowed_state_idx}")


    
    def position_to_state_index(self, tuple_position = None): 
        grid_width = self.env.grid.width -2
        if tuple_position is None:
            direction = self.env.agent_dir
            x, y = self.env.agent_pos

        else:
            if not isinstance(tuple_position, tuple) or len(tuple_position) != 3:
                raise ValueError(f"Invalid position format: {tuple_position}")
            x, y, direction = tuple_position
        return np.int64(((y-1) * grid_width + (x-1)) * 4 + direction) 
    
    def state_index_to_position(self, state_idx):
        """Converts a scalar state index back into (x, y, direction)."""
        grid_width = self.env.grid.width-2
        
        direction = state_idx % 4
        linear_idx = state_idx // 4

        y, x = divmod(linear_idx, grid_width)  # Convert to (x, y)
        
        return x+1, y+1, direction
    
    def find_state_indexes(self, env):
        """Counts all states except walls and barriers"""
        state_indexes_list = []
        for x in range(1, env.grid.width-1):
            for y in range(1, env.grid.height-1):
                if env.grid.get(x, y) is None: #grabs all empty spaces
                    for direction in range(4):
                        state_index = self.position_to_state_index((x, y, direction))
                        state_indexes_list.append(state_index)
        return state_indexes_list        
    
    
    def train(self, epochs):
        goal_states = [self.position_to_state_index((8, 1, d)) for d in range(4)] #goal state index
        
        for epoch in range(epochs):
            current_state = np.random.choice(self.allowed_state_idx)
            x,y,dir = self.state_index_to_position(current_state)
            self.env.agent_pos = (x,y)
            self.env.agent_dir = dir
            print(f"Epoch {epoch}: Starting state: {current_state}")
            print(f"Epoch {epoch}: Starting position: {self.state_index_to_position(current_state)}")

            while current_state not in goal_states:
                # #replace current index with its table index
                # table_index = self.state_to_index[current_state]
                # Epsilon-greedy action selection
                if np.random.rand() < self.epsilon:
                    action = self.env.action_space.sample()
                    print(f"random action: {action}, exploring")
                else:
                    action = np.argmax(self.Q_table[current_state])
                    print(f"greedy action: {action}, exploiting")


                #transition to the next state
                next_obs, _, done, _, _ = self.env.step(action)

                # print(f"next_observation: {next_obs}")
                next_state = self.position_to_state_index()
                print(f"next_state: {next_state}")
                print(f"next  step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")
                #reward (-1 for each step thats not the gaol)
                reward = 0 if next_state in goal_states else -1

                self.Q_table[current_state, action] += self.learning_rate * (reward + self.discount_factor * np.max(self.Q_table[next_state]) - self.Q_table[current_state, action])
                #update state
                if next_state in goal_states:
                    break
                # assert(False)
                current_state = next_state
        
        
    

    def run_policy_2(self):
        """Run the environment using the learned policy from a Q-table."""

        self.env.reset()[0]  # Reset environment
        current_state = self.position_to_state_index()  # Convert starting position to index
        done = False
        step_count = 0  # Track steps to prevent infinite loops

        while not done and step_count < 100:  # Prevent infinite loops
            # Debugging: Print current state and Q-values
            print(f"Step {step_count}: State {current_state}")
            print(f"Q-values: {self.Q_table[current_state]}")
            
            action = np.argmax(self.Q_table[current_state])  # Choose best action
            print(f"Chosen action: {action}")

            # Before taking the step, print agent's current position
            print(f"Before step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")

            next_obs, _, done, _, _ = self.env.step(action)  # Take action

            # After step, print agent's new position
            print(f"After step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")

            next_state = self.position_to_state_index()  # Convert new state

            # Detect if the agent is looping in the same state
            if next_state == current_state:
                print(f"⚠️ Warning: Agent is stuck! Current state {current_state} is the same as next state {next_state}.")
                break  # Prevent infinite loop

            self.env.render()  # Visualize movement
            current_state = next_state  # Update current state
            step_count += 1

# %% [markdown]
# Q Learning With Greedy Policy Normlization

# %%
class Qlearning:
    def __init__(
        self,
        env,
        learning_rate = 0.9,
        discount_factor = 0.9,
        epsilon = 0.5,
        epochs = 1000
         
    ):
        self.env = env # MiniGrid environment called from the class Minigrid
        self.num_states = np.int64(env.count_states())
        self.num_actions = env.action_space.n
        self.Q_table = np.zeros((((env.width -2) * (env.height -2) *4), self.num_actions)) # Q table has goal states in it as well
        # print(f"Q table shape: {self.Q_table.shape}")
        self.learning_rate = learning_rate
        self.discount_factor = discount_factor # discount factor
        self.epsilon =  epsilon # exploration probability
        self.epochs = epochs


        self.allowed_state_idx = self.find_state_indexes(env)
        # print(f"allowed state indexes: {self.allowed_state_idx}")


    
    def position_to_state_index(self, tuple_position = None): 
        grid_width = self.env.grid.width -2
        if tuple_position is None:
            direction = self.env.agent_dir
            x, y = self.env.agent_pos

        else:
            if not isinstance(tuple_position, tuple) or len(tuple_position) != 3:
                raise ValueError(f"Invalid position format: {tuple_position}")
            x, y, direction = tuple_position
        return np.int64(((y-1) * grid_width + (x-1)) * 4 + direction) 
    
    def state_index_to_position(self, state_idx):
        """Converts a scalar state index back into (x, y, direction)."""
        grid_width = self.env.grid.width-2
        
        direction = state_idx % 4
        linear_idx = state_idx // 4

        y, x = divmod(linear_idx, grid_width)  # Convert to (x, y)
        
        return x+1, y+1, direction
    
    def find_state_indexes(self, env):
        """Counts all states except walls and barriers"""
        state_indexes_list = []
        for x in range(1, env.grid.width-1):
            for y in range(1, env.grid.height-1):
                if env.grid.get(x, y) is None: #grabs all empty spaces
                    for direction in range(4):
                        state_index = self.position_to_state_index((x, y, direction))
                        state_indexes_list.append(state_index)
        return state_indexes_list        
    
    
    def train(self, epochs):
        goal_states = [self.position_to_state_index((8, 1, d)) for d in range(4)] #goal state index
        
        for epoch in range(epochs):
            current_state = np.random.choice(self.allowed_state_idx)
            x,y,dir = self.state_index_to_position(current_state)
            self.env.agent_pos = (x,y)
            self.env.agent_dir = dir
            print(f"Epoch {epoch}: Starting state: {current_state}")
            print(f"Epoch {epoch}: Starting position: {self.state_index_to_position(current_state)}")

            while current_state not in goal_states:
                # #replace current index with its table index
                # table_index = self.state_to_index[current_state]
                # Epsilon-greedy action selection
                if np.random.rand() < self.epsilon:
                    action = self.env.action_space.sample()
                    print(f"random action: {action}, exploring")
                else:
                    action = np.argmax(self.Q_table[current_state])
                    print(f"greedy action: {action}, exploiting")


                #transition to the next state
                next_obs, _, done, _, _ = self.env.step(action)

                # print(f"next_observation: {next_obs}")
                next_state = self.position_to_state_index()
                print(f"next_state: {next_state}")
                print(f"next  step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")
                #reward (-1 for each step thats not the gaol)
                reward = 0 if next_state in goal_states else -1

                self.Q_table[current_state, action] += self.learning_rate * (reward + self.discount_factor * np.max(self.Q_table[next_state]) - self.Q_table[current_state, action])
                #update state
                if next_state in goal_states:
                    break
                # assert(False)
                current_state = next_state
        
        
    

    def run_policy_2(self):
        """Run the environment using the learned policy from a Q-table."""

        self.env.reset()[0]  # Reset environment
        current_state = self.position_to_state_index()  # Convert starting position to index
        done = False
        step_count = 0  # Track steps to prevent infinite loops

        while not done and step_count < 100:  # Prevent infinite loops
            # Debugging: Print current state and Q-values
            print(f"Step {step_count}: State {current_state}")
            print(f"Q-values: {self.Q_table[current_state]}")
            
            action = np.argmax(self.Q_table[current_state])  # Choose best action
            print(f"Chosen action: {action}")

            # Before taking the step, print agent's current position
            print(f"Before step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")

            next_obs, _, done, _, _ = self.env.step(action)  # Take action

            # After step, print agent's new position
            print(f"After step: Agent Pos: {self.env.agent_pos}, Dir: {self.env.agent_dir}")

            next_state = self.position_to_state_index()  # Convert new state

            # Detect if the agent is looping in the same state
            if next_state == current_state:
                print(f"⚠️ Warning: Agent is stuck! Current state {current_state} is the same as next state {next_state}.")
                break  # Prevent infinite loop

            self.env.render()  # Visualize movement
            current_state = next_state  # Update current state
            step_count += 1

# %%
env = SimpleEnv(render_mode="human") 
env.reset()
q_training = Qlearning(env)
q_training.train(500)
# Out:
# Epoch 0: Starting state: 24
# Epoch 0: Starting position: (np.int64(7), np.int64(1), np.int64(0))
# greedy action: 0, exploiting
# next_state: 27
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 3
# random action: 0, exploring
# next_state: 26
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 2
# random action: 1, exploring
# next_state: 27
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 3
# greedy action: 1, exploiting
# next_state: 24
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 0
# greedy action: 1, exploiting
# next_state: 25
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 1
# greedy action: 0, exploiting
# next_state: 24
# next  step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 0
# greedy action: 2, exploiting
# next_state: 28
# next  step: Agent Pos: (np.int64(8), np.int64(1)), Dir: 0
# Epoch 1: Starting state: 254
# Epoch 1: Starting position: (np.int64(8), np.int64(8), np.int64(2))
# random action: 1, exploring
# next_state: 255
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 3
# greedy action: 0, exploiting
# next_state: 254
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 2
# greedy action: 0, exploiting
# next_state: 253
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 253
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 252
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 0
# greedy action: 0, exploiting
# next_state: 255
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 3
# greedy action: 1, exploiting
# next_state: 252
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 0
# random action: 2, exploring
# next_state: 252
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 0
# random action: 2, exploring
# next_state: 252
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 0
# random action: 0, exploring
# next_state: 255
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 3
# random action: 0, exploring
# next_state: 254
# next  step: Agent Pos: (np.int64(8), np.int64(8)), Dir: 2
# greedy action: 2, exploiting
# next_state: 250
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 2
# greedy action: 0, exploiting
# next_state: 249
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 1
# random action: 0, exploring
# next_state: 248
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 0
# greedy action: 0, exploiting
# next_state: 251
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 3
# random action: 2, exploring
# next_state: 219
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 3
# random action: 0, exploring
# next_state: 218
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 2
# greedy action: 0, exploiting
# next_state: 217
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 218
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 2
# greedy action: 1, exploiting
# next_state: 219
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 216
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 0
# greedy action: 0, exploiting
# next_state: 219
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 187
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 3
# greedy action: 0, exploiting
# next_state: 186
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 2
# random action: 2, exploring
# next_state: 182
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 2
# random action: 1, exploring
# next_state: 183
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 3
# random action: 1, exploring
# next_state: 180
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 0
# greedy action: 0, exploiting
# next_state: 183
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 3
# random action: 1, exploring
# next_state: 180
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 0
# greedy action: 1, exploiting
# next_state: 181
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 1
# greedy action: 0, exploiting
# next_state: 180
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 0
# greedy action: 2, exploiting
# next_state: 184
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 0
# random action: 0, exploring
# next_state: 187
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 3
# random action: 2, exploring
# next_state: 155
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 152
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 0
# random action: 2, exploring
# next_state: 156
# next  step: Agent Pos: (np.int64(8), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 159
# next  step: Agent Pos: (np.int64(8), np.int64(5)), Dir: 3
# greedy action: 0, exploiting
# next_state: 158
# next  step: Agent Pos: (np.int64(8), np.int64(5)), Dir: 2
# random action: 2, exploring
# next_state: 154
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 153
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 154
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 2
# random action: 0, exploring
# next_state: 153
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 154
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 2
# greedy action: 1, exploiting
# next_state: 155
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 3
# random action: 0, exploring
# next_state: 154
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 150
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 149
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 150
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 2
# random action: 2, exploring
# next_state: 146
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 145
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 144
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 147
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 3
# random action: 2, exploring
# next_state: 115
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 112
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 115
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 114
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 115
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 3
# greedy action: 2, exploiting
# next_state: 115
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 112
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 0
# random action: 2, exploring
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# random action: 0, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# random action: 0, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# greedy action: 2, exploiting
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# random action: 2, exploring
# next_state: 124
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 127
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 126
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 125
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 124
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 0
# random action: 2, exploring
# next_state: 124
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 125
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 124
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 0
# random action: 2, exploring
# next_state: 124
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 0
# random action: 0, exploring
# next_state: 127
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 126
# next  step: Agent Pos: (np.int64(8), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 122
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 121
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# greedy action: 1, exploiting
# next_state: 121
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 1
# greedy action: 1, exploiting
# next_state: 122
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 2
# greedy action: 1, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 122
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# greedy action: 2, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 122
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 2
# greedy action: 2, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# random action: 2, exploring
# next_state: 149
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 150
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 2
# random action: 1, exploring
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 0, exploring
# next_state: 150
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 2
# random action: 1, exploring
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# greedy action: 2, exploiting
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# greedy action: 1, exploiting
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 114
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 113
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 112
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 0
# random action: 0, exploring
# next_state: 115
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 112
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 0
# greedy action: 1, exploiting
# next_state: 113
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 114
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 110
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 109
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 108
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 111
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 79
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 3
# greedy action: 0, exploiting
# next_state: 78
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 2
# greedy action: 0, exploiting
# next_state: 77
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 1
# random action: 1, exploring
# next_state: 78
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 2
# greedy action: 1, exploiting
# next_state: 79
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 3
# random action: 1, exploring
# next_state: 76
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 0
# random action: 1, exploring
# next_state: 77
# next  step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 1
# random action: 2, exploring
# next_state: 109
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 110
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 111
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 108
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 109
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 108
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 0
# greedy action: 2, exploiting
# next_state: 112
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 0
# greedy action: 1, exploiting
# next_state: 113
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 1
# greedy action: 2, exploiting
# next_state: 145
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 1
# greedy action: 1, exploiting
# next_state: 146
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 2
# greedy action: 1, exploiting
# next_state: 147
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 3
# random action: 0, exploring
# next_state: 146
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 142
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 2
# random action: 2, exploring
# next_state: 138
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 2
# random action: 1, exploring
# next_state: 139
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 3
# random action: 0, exploring
# next_state: 138
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 137
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 136
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 0
# random action: 1, exploring
# next_state: 137
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 138
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 134
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 133
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 1
# random action: 0, exploring
# next_state: 132
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 0
# random action: 2, exploring
# next_state: 136
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 139
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 3
# greedy action: 1, exploiting
# next_state: 136
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 0
# random action: 1, exploring
# next_state: 137
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 1
# greedy action: 2, exploiting
# next_state: 137
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 136
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 0
# random action: 0, exploring
# next_state: 139
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 3
# greedy action: 2, exploiting
# next_state: 107
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 106
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 107
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 106
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 107
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 75
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 3
# greedy action: 0, exploiting
# next_state: 74
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 2
# random action: 2, exploring
# next_state: 70
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 2
# greedy action: 0, exploiting
# next_state: 69
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 1
# greedy action: 0, exploiting
# next_state: 68
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 0
# greedy action: 0, exploiting
# next_state: 71
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 3
# greedy action: 0, exploiting
# next_state: 70
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 2
# random action: 0, exploring
# next_state: 69
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 1
# random action: 1, exploring
# next_state: 70
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 2
# greedy action: 1, exploiting
# next_state: 71
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 3
# greedy action: 1, exploiting
# next_state: 68
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 0
# random action: 2, exploring
# next_state: 72
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 0
# greedy action: 0, exploiting
# next_state: 75
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 3
# greedy action: 1, exploiting
# next_state: 72
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 0
# random action: 0, exploring
# next_state: 75
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 3
# greedy action: 2, exploiting
# next_state: 43
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 3
# random action: 0, exploring
# next_state: 42
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 2
# greedy action: 0, exploiting
# next_state: 41
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 1
# random action: 1, exploring
# next_state: 42
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 2
# random action: 1, exploring
# next_state: 43
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 3
# greedy action: 1, exploiting
# next_state: 40
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 0
# random action: 2, exploring
# next_state: 44
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 0
# greedy action: 0, exploiting
# next_state: 47
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 3
# greedy action: 0, exploiting
# next_state: 46
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 2
# greedy action: 0, exploiting
# next_state: 45
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 1
# greedy action: 0, exploiting
# next_state: 44
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 0
# greedy action: 1, exploiting
# next_state: 45
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 1
# greedy action: 1, exploiting
# next_state: 46
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 2
# greedy action: 1, exploiting
# next_state: 47
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 3
# greedy action: 1, exploiting
# next_state: 44
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 0
# random action: 0, exploring
# next_state: 47
# next  step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 3
# greedy action: 2, exploiting
# next_state: 15
# next  step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 3
# greedy action: 0, exploiting
# next_state: 14
# next  step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 2
# random action: 1, exploring
# next_state: 15
# next  step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 3
# greedy action: 1, exploiting
# next_state: 12
# next  step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 0
# random action: 2, exploring
# next_state: 16
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 0
# random action: 2, exploring
# next_state: 20
# next  step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 0
# random action: 0, exploring
# next_state: 23
# next  step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 3
# random action: 2, exploring
# next_state: 23
# next  step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 3
# greedy action: 0, exploiting
# next_state: 22
# next  step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 2
# random action: 2, exploring
# next_state: 18
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 2
# random action: 1, exploring
# next_state: 19
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 3
# greedy action: 0, exploiting
# next_state: 18
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 2
# random action: 1, exploring
# next_state: 19
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 3
# random action: 1, exploring
# next_state: 16
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 0
# greedy action: 0, exploiting
# next_state: 19
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 3
# greedy action: 2, exploiting
# next_state: 19
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 3
# random action: 0, exploring
# next_state: 18
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 2
# greedy action: 0, exploiting
# next_state: 17
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 1
# greedy action: 0, exploiting
# next_state: 16
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 0
# random action: 1, exploring
# next_state: 17
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 1
# greedy action: 1, exploiting
# next_state: 18
# next  step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 2
# random action: 2, exploring
# next_state: 14
# next  step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 2
# random action: 2, exploring
# next_state: 10
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 2
# greedy action: 0, exploiting
# next_state: 9
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 1
# greedy action: 0, exploiting
# next_state: 8
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 0
# greedy action: 0, exploiting
# next_state: 11
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 3
# random action: 1, exploring
# next_state: 8
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 0
# greedy action: 1, exploiting
# next_state: 9
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 1
# random action: 1, exploring
# next_state: 10
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 2
# random action: 0, exploring
# next_state: 9
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 1
# greedy action: 2, exploiting
# next_state: 41
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 1
# random action: 2, exploring
# next_state: 73
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 1
# random action: 2, exploring
# next_state: 105
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 106
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 102
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 103
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 102
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 101
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 100
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 101
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 1
# greedy action: 1, exploiting
# next_state: 102
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 2
# greedy action: 2, exploiting
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 99
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 97
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 96
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 99
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 3
# greedy action: 1, exploiting
# next_state: 96
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 0
# greedy action: 1, exploiting
# next_state: 97
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 1
# random action: 2, exploring
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# random action: 0, exploring
# next_state: 128
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# random action: 2, exploring
# next_state: 99
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 97
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 98
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 2
# greedy action: 1, exploiting
# next_state: 99
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 96
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 0
# random action: 2, exploring
# next_state: 100
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 101
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 102
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 101
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 1
# random action: 1, exploring
# next_state: 102
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 103
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 3
# greedy action: 1, exploiting
# next_state: 100
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 103
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 100
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 0
# random action: 0, exploring
# next_state: 103
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 3
# greedy action: 2, exploiting
# next_state: 71
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 3
# greedy action: 2, exploiting
# next_state: 39
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 3
# greedy action: 0, exploiting
# next_state: 38
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 2
# greedy action: 0, exploiting
# next_state: 37
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 1
# random action: 0, exploring
# next_state: 36
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 0
# greedy action: 0, exploiting
# next_state: 39
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 3
# random action: 0, exploring
# next_state: 38
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 2
# random action: 1, exploring
# next_state: 39
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 3
# greedy action: 1, exploiting
# next_state: 36
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 0
# random action: 2, exploring
# next_state: 40
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 0
# greedy action: 0, exploiting
# next_state: 43
# next  step: Agent Pos: (np.int64(3), np.int64(2)), Dir: 3
# greedy action: 2, exploiting
# next_state: 11
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 3
# greedy action: 0, exploiting
# next_state: 10
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 2
# greedy action: 1, exploiting
# next_state: 11
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 3
# greedy action: 2, exploiting
# next_state: 11
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 3
# greedy action: 0, exploiting
# next_state: 10
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 2
# random action: 2, exploring
# next_state: 6
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 2
# random action: 0, exploring
# next_state: 5
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 1
# greedy action: 0, exploiting
# next_state: 4
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 0
# greedy action: 0, exploiting
# next_state: 7
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 3
# random action: 1, exploring
# next_state: 4
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 0
# greedy action: 1, exploiting
# next_state: 5
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 1
# greedy action: 1, exploiting
# next_state: 6
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 2
# random action: 0, exploring
# next_state: 5
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 1
# random action: 0, exploring
# next_state: 4
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 0
# greedy action: 2, exploiting
# next_state: 8
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 0
# random action: 0, exploring
# next_state: 11
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 3
# random action: 0, exploring
# next_state: 10
# next  step: Agent Pos: (np.int64(3), np.int64(1)), Dir: 2
# random action: 2, exploring
# next_state: 6
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 2
# random action: 0, exploring
# next_state: 5
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 1
# greedy action: 2, exploiting
# next_state: 37
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 1
# greedy action: 1, exploiting
# next_state: 38
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 2
# random action: 1, exploring
# next_state: 39
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 3
# random action: 0, exploring
# next_state: 38
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 2
# greedy action: 2, exploiting
# next_state: 34
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 2
# greedy action: 0, exploiting
# next_state: 33
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 1
# random action: 0, exploring
# next_state: 32
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 0
# random action: 2, exploring
# next_state: 36
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 0
# greedy action: 1, exploiting
# next_state: 37
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 1
# random action: 2, exploring
# next_state: 69
# next  step: Agent Pos: (np.int64(2), np.int64(3)), Dir: 1
# greedy action: 2, exploiting
# next_state: 101
# next  step: Agent Pos: (np.int64(2), np.int64(4)), Dir: 1
# random action: 2, exploring
# next_state: 133
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 1
# greedy action: 1, exploiting
# next_state: 134
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 2
# greedy action: 1, exploiting
# next_state: 135
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 3
# greedy action: 0, exploiting
# next_state: 134
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# greedy action: 1, exploiting
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# greedy action: 0, exploiting
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# random action: 0, exploring
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# random action: 1, exploring
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# random action: 1, exploring
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# greedy action: 1, exploiting
# next_state: 128
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 0
# random action: 0, exploring
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# greedy action: 0, exploiting
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# greedy action: 2, exploiting
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# greedy action: 0, exploiting
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# greedy action: 2, exploiting
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# random action: 0, exploring
# next_state: 128
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 0
# random action: 0, exploring
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# greedy action: 1, exploiting
# next_state: 128
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 0
# greedy action: 1, exploiting
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# greedy action: 2, exploiting
# next_state: 129
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 128
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 0
# greedy action: 2, exploiting
# next_state: 132
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 0
# random action: 2, exploring
# next_state: 136
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 0
# random action: 2, exploring
# next_state: 140
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 0
# random action: 0, exploring
# next_state: 143
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 140
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 0
# greedy action: 1, exploiting
# next_state: 141
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 140
# next  step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 0
# greedy action: 2, exploiting
# next_state: 144
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 0
# greedy action: 1, exploiting
# next_state: 145
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 1
# random action: 0, exploring
# next_state: 144
# next  step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 0
# greedy action: 2, exploiting
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# greedy action: 1, exploiting
# next_state: 149
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# greedy action: 2, exploiting
# next_state: 152
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 155
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 3
# greedy action: 2, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# greedy action: 1, exploiting
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 121
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 1
# greedy action: 2, exploiting
# next_state: 153
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 1
# greedy action: 0, exploiting
# next_state: 152
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 0
# random action: 1, exploring
# next_state: 153
# next  step: Agent Pos: (np.int64(7), np.int64(5)), Dir: 1
# greedy action: 2, exploiting
# next_state: 185
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 1
# greedy action: 0, exploiting
# next_state: 184
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 0
# greedy action: 1, exploiting
# next_state: 185
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 1
# greedy action: 1, exploiting
# next_state: 186
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 2
# random action: 0, exploring
# next_state: 185
# next  step: Agent Pos: (np.int64(7), np.int64(6)), Dir: 1
# greedy action: 2, exploiting
# next_state: 217
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 216
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 0
# greedy action: 1, exploiting
# next_state: 217
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 218
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 217
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 1
# random action: 0, exploring
# next_state: 216
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 219
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 218
# next  step: Agent Pos: (np.int64(7), np.int64(7)), Dir: 2
# random action: 2, exploring
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 212
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 213
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# random action: 2, exploring
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# greedy action: 2, exploiting
# next_state: 206
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 205
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 204
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 0
# greedy action: 0, exploiting
# next_state: 207
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 206
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 207
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 204
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 0
# random action: 2, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# greedy action: 1, exploiting
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 0, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# greedy action: 0, exploiting
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# greedy action: 2, exploiting
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 1, exploring
# next_state: 242
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 2
# greedy action: 0, exploiting
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 240
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# random action: 1, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 240
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# random action: 0, exploring
# next_state: 243
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# greedy action: 0, exploiting
# next_state: 242
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 2
# greedy action: 1, exploiting
# next_state: 243
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# greedy action: 1, exploiting
# next_state: 240
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# random action: 2, exploring
# next_state: 244
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 0
# random action: 1, exploring
# next_state: 245
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 244
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 0
# random action: 0, exploring
# next_state: 247
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 3
# random action: 2, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 212
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 0
# greedy action: 0, exploiting
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 2, exploring
# next_state: 183
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 3
# random action: 2, exploring
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# greedy action: 1, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 114
# next  step: Agent Pos: (np.int64(5), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 110
# next  step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 2
# random action: 2, exploring
# next_state: 106
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 2
# random action: 1, exploring
# next_state: 107
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 3
# greedy action: 1, exploiting
# next_state: 104
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 107
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 3
# random action: 2, exploring
# next_state: 75
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 3
# greedy action: 0, exploiting
# next_state: 74
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 2
# greedy action: 0, exploiting
# next_state: 73
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 1
# random action: 1, exploring
# next_state: 74
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 2
# random action: 0, exploring
# next_state: 73
# next  step: Agent Pos: (np.int64(3), np.int64(3)), Dir: 1
# random action: 2, exploring
# next_state: 105
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 104
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 0
# greedy action: 1, exploiting
# next_state: 105
# next  step: Agent Pos: (np.int64(3), np.int64(4)), Dir: 1
# greedy action: 2, exploiting
# next_state: 137
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 1
# greedy action: 1, exploiting
# next_state: 138
# next  step: Agent Pos: (np.int64(3), np.int64(5)), Dir: 2
# random action: 2, exploring
# next_state: 134
# next  step: Agent Pos: (np.int64(2), np.int64(5)), Dir: 2
# random action: 2, exploring
# next_state: 130
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 2
# random action: 1, exploring
# next_state: 131
# next  step: Agent Pos: (np.int64(1), np.int64(5)), Dir: 3
# greedy action: 2, exploiting
# next_state: 99
# next  step: Agent Pos: (np.int64(1), np.int64(4)), Dir: 3
# greedy action: 2, exploiting
# next_state: 67
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 3
# greedy action: 0, exploiting
# next_state: 66
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 2
# greedy action: 0, exploiting
# next_state: 65
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 1
# random action: 1, exploring
# next_state: 66
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 2
# greedy action: 1, exploiting
# next_state: 67
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 3
# greedy action: 1, exploiting
# next_state: 64
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 0
# random action: 0, exploring
# next_state: 67
# next  step: Agent Pos: (np.int64(1), np.int64(3)), Dir: 3
# greedy action: 2, exploiting
# next_state: 35
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 3
# greedy action: 0, exploiting
# next_state: 34
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 2
# random action: 1, exploring
# next_state: 35
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 3
# greedy action: 1, exploiting
# next_state: 32
# next  step: Agent Pos: (np.int64(1), np.int64(2)), Dir: 0
# random action: 2, exploring
# next_state: 36
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 0
# random action: 1, exploring
# next_state: 37
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 1
# greedy action: 0, exploiting
# next_state: 36
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 0
# greedy action: 0, exploiting
# next_state: 39
# next  step: Agent Pos: (np.int64(2), np.int64(2)), Dir: 3
# random action: 2, exploring
# next_state: 7
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 3
# random action: 0, exploring
# next_state: 6
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 2
# greedy action: 1, exploiting
# next_state: 7
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 3
# random action: 0, exploring
# next_state: 6
# next  step: Agent Pos: (np.int64(2), np.int64(1)), Dir: 2
# ...
# next_state: 204
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 0
# random action: 2, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 0, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 179
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 3
# random action: 0, exploring
# next_state: 178
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 2
# random action: 2, exploring
# next_state: 178
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 2
# greedy action: 0, exploiting
# next_state: 177
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 1
# random action: 0, exploring
# next_state: 176
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 0
# greedy action: 1, exploiting
# next_state: 177
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 1
# greedy action: 1, exploiting
# next_state: 178
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 2
# greedy action: 0, exploiting
# next_state: 177
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 1
# random action: 2, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 240
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# greedy action: 0, exploiting
# next_state: 243
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# greedy action: 2, exploiting
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# greedy action: 2, exploiting
# next_state: 212
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 0
# greedy action: 1, exploiting
# next_state: 213
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 1
# random action: 2, exploring
# next_state: 245
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 1
# random action: 1, exploring
# next_state: 246
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 2
# random action: 2, exploring
# next_state: 242
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 2
# greedy action: 1, exploiting
# next_state: 243
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# random action: 2, exploring
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 211
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 179
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 3
# greedy action: 1, exploiting
# next_state: 176
# next  step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 0
# greedy action: 2, exploiting
# next_state: 180
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 0
# greedy action: 0, exploiting
# next_state: 183
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 3
# random action: 0, exploring
# next_state: 182
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 2
# random action: 0, exploring
# next_state: 181
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 1
# greedy action: 2, exploiting
# next_state: 213
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 1
# greedy action: 1, exploiting
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 213
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 212
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 212
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 0, exploring
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 213
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 214
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 2
# greedy action: 2, exploiting
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# greedy action: 2, exploiting
# next_state: 206
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 2
# greedy action: 0, exploiting
# next_state: 205
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 206
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 2
# greedy action: 2, exploiting
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# greedy action: 1, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# random action: 0, exploring
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# greedy action: 2, exploiting
# next_state: 198
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 2
# greedy action: 1, exploiting
# next_state: 199
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 3
# random action: 0, exploring
# next_state: 198
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 199
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 199
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 196
# next  step: Agent Pos: (np.int64(2), np.int64(7)), Dir: 0
# random action: 2, exploring
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# random action: 0, exploring
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 0, exploring
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# random action: 1, exploring
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# greedy action: 0, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 2, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 0, exploiting
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# greedy action: 1, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# random action: 0, exploring
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# greedy action: 0, exploiting
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# random action: 1, exploring
# next_state: 202
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 2
# random action: 1, exploring
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# greedy action: 2, exploiting
# next_state: 233
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 233
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 1
# greedy action: 0, exploiting
# next_state: 232
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 0
# random action: 0, exploring
# next_state: 235
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 3
# random action: 0, exploring
# next_state: 234
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 2
# greedy action: 1, exploiting
# next_state: 235
# next  step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 3
# greedy action: 2, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# greedy action: 0, exploiting
# next_state: 203
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 3
# greedy action: 1, exploiting
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 201
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 1
# greedy action: 0, exploiting
# next_state: 200
# next  step: Agent Pos: (np.int64(3), np.int64(7)), Dir: 0
# random action: 2, exploring
# next_state: 204
# next  step: Agent Pos: (np.int64(4), np.int64(7)), Dir: 0
# random action: 2, exploring
# next_state: 208
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 0
# random action: 1, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# greedy action: 1, exploiting
# next_state: 210
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 2
# random action: 0, exploring
# next_state: 209
# next  step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 241
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 1
# random action: 0, exploring
# next_state: 240
# next  step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# greedy action: 2, exploiting
# next_state: 244
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 0
# random action: 2, exploring
# next_state: 248
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 0
# random action: 0, exploring
# next_state: 251
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 3
# random action: 0, exploring
# next_state: 250
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 2
# random action: 1, exploring
# next_state: 251
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 3
# greedy action: 1, exploiting
# next_state: 248
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 0
# random action: 1, exploring
# next_state: 249
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 1
# random action: 2, exploring
# next_state: 249
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 1
# greedy action: 2, exploiting
# next_state: 249
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 1
# random action: 0, exploring
# next_state: 248
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 0
# greedy action: 0, exploiting
# next_state: 251
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 3
# greedy action: 0, exploiting
# next_state: 250
# next  step: Agent Pos: (np.int64(7), np.int64(8)), Dir: 2
# greedy action: 2, exploiting
# next_state: 246
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 2
# greedy action: 1, exploiting
# next_state: 247
# next  step: Agent Pos: (np.int64(6), np.int64(8)), Dir: 3
# random action: 2, exploring
# next_state: 215
# next  step: Agent Pos: (np.int64(6), np.int64(7)), Dir: 3
# random action: 2, exploring
# next_state: 183
# next  step: Agent Pos: (np.int64(6), np.int64(6)), Dir: 3
# greedy action: 2, exploiting
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 0, exploring
# next_state: 150
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 2
# greedy action: 1, exploiting
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# greedy action: 0, exploiting
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 1, exploring
# next_state: 148
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 0
# random action: 0, exploring
# next_state: 151
# next  step: Agent Pos: (np.int64(6), np.int64(5)), Dir: 3
# random action: 2, exploring
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# random action: 1, exploring
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# random action: 1, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# greedy action: 1, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# greedy action: 0, exploiting
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 119
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 3
# greedy action: 0, exploiting
# next_state: 118
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 2
# random action: 0, exploring
# next_state: 117
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 1
# random action: 0, exploring
# next_state: 116
# next  step: Agent Pos: (np.int64(6), np.int64(4)), Dir: 0
# greedy action: 2, exploiting
# next_state: 120
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 0
# greedy action: 0, exploiting
# next_state: 123
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 3
# random action: 0, exploring
# next_state: 122
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 2
# greedy action: 0, exploiting
# next_state: 121
# next  step: Agent Pos: (np.int64(7), np.int64(4)), Dir: 1
# random action: 0, exploring
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 4
#       2 env.reset()
#       3 q_training = Qlearning(env)
# ----> 4 q_training.train(500)
#
# Cell In[17], line 86, in Qlearning.train(self, epochs)
#      82     print(f"greedy action: {action}, exploiting")
#      85 #transition to the next state
# ---> 86 next_obs, _, done, _, _ = self.env.step(action)
#      88 # print(f"next_observation: {next_obs}")
#      89 next_state = self.position_to_state_index()
#
# File ~/miniconda3/envs/IBP/lib/python3.11/site-packages/minigrid/minigrid_env.py:591, in MiniGridEnv.step(self, action)
#     588     truncated = True
#     590 if self.render_mode == "human":
# --> 591     self.render()
#     593 obs = self.gen_obs()
#     595 return obs, reward, terminated, truncated, {}
#
# File ~/miniconda3/envs/IBP/lib/python3.11/site-packages/minigrid/minigrid_env.py:781, in MiniGridEnv.render(self)
#     779     self.window.blit(bg, (0, 0))
#     780     pygame.event.pump()
# --> 781     self.clock.tick(self.metadata["render_fps"])
#     782     pygame.display.flip()
#     784 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
env_human = SimpleEnv(render_mode="human") #make same env but in human mode 

q_training.env= env_human #switch out the env in q training with human env
q_training.run_policy_2() #run the policy in the human env
# Out:
# Step 0: State 224
# Q-values: [-8.73074808 -8.72171911 -8.64914764]
# Chosen action: 2
# Before step: Agent Pos: (1, 8), Dir: 0
# After step: Agent Pos: (np.int64(2), np.int64(8)), Dir: 0
# Step 1: State 228
# Q-values: [-8.76249664 -8.78058289 -8.49905365]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(2), np.int64(8)), Dir: 0
# After step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 0
# Step 2: State 232
# Q-values: [-8.64624854 -8.64880725 -8.33228183]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(3), np.int64(8)), Dir: 0
# After step: Agent Pos: (np.int64(4), np.int64(8)), Dir: 0
# Step 3: State 236
# Q-values: [-8.49905362 -8.49905365 -8.14697981]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(8)), Dir: 0
# After step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# Step 4: State 240
# Q-values: [-7.94108868 -8.3322568  -8.3288565 ]
# Chosen action: 0
# Before step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 0
# After step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# Step 5: State 243
# Q-values: [-8.1469794  -8.1469714  -7.71232075]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(5), np.int64(8)), Dir: 3
# After step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# Step 6: State 211
# Q-values: [-7.94108868 -7.94108868 -7.45813417]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(5), np.int64(7)), Dir: 3
# After step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 3
# Step 7: State 179
# Q-values: [-7.71232075 -7.71232075 -7.17570464]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(5), np.int64(6)), Dir: 3
# After step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 3
# Step 8: State 147
# Q-values: [-6.86189404 -7.45813417 -6.86189404]
# Chosen action: 0
# Before step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 3
# After step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 2
# Step 9: State 146
# Q-values: [-7.17570464 -7.17570464 -6.5132156 ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(5), np.int64(5)), Dir: 2
# After step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 2
# Step 10: State 142
# Q-values: [-6.86189404 -6.12579511 -6.86189404]
# Chosen action: 1
# Before step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 2
# After step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 3
# Step 11: State 143
# Q-values: [-6.5132156 -6.5132156 -5.6953279]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(5)), Dir: 3
# After step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 3
# Step 12: State 111
# Q-values: [-6.12579511 -6.12579511 -5.217031  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(4)), Dir: 3
# After step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 3
# Step 13: State 79
# Q-values: [-5.6953279 -5.6953279 -4.68559  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(3)), Dir: 3
# After step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 3
# Step 14: State 47
# Q-values: [-5.217031 -4.68559  -4.0951  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(2)), Dir: 3
# After step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 3
# Step 15: State 15
# Q-values: [-4.68559 -3.439   -4.0951 ]
# Chosen action: 1
# Before step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 3
# After step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 0
# Step 16: State 12
# Q-values: [-4.0951 -4.0951 -2.71  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(4), np.int64(1)), Dir: 0
# After step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 0
# Step 17: State 16
# Q-values: [-3.439 -3.439 -1.9  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(5), np.int64(1)), Dir: 0
# After step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 0
# Step 18: State 20
# Q-values: [-2.71 -2.71 -1.  ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(6), np.int64(1)), Dir: 0
# After step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 0
# Step 19: State 24
# Q-values: [-1.9 -1.9  0. ]
# Chosen action: 2
# Before step: Agent Pos: (np.int64(7), np.int64(1)), Dir: 0
# After step: Agent Pos: (np.int64(8), np.int64(1)), Dir: 0
